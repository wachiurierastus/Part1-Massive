# %%
from __future__ import annotations

import json
import os
from typing import Optional

import pandas as pd
from pandas import DataFrame

# %%
english_file = pd.read_json("en-US.jsonl", lines=True)

# %%
sample = pd.read_json('data\\af-ZA.jsonl', lines=True)

# %%
sample.head()
# Out:
#    id locale partition scenario             intent  \
# 0   0  af-ZA      test    alarm          alarm_set
# 1   1  af-ZA     train    alarm          alarm_set
# 2   2  af-ZA     train    alarm          alarm_set
# 3   3  af-ZA      test    audio  audio_volume_mute
# 4   4  af-ZA     train    audio  audio_volume_mute
#
#                                        utt  \
# 0     maak my wakker om vyf v. m. die week
# 1  maak my wakker nege-uur v. m. op vrydag
# 2    stel 'n alarm vir twee ure van nou af
# 3                                     stil
# 4                          janneman stilte
#
#                                            annot_utt  worker_id  \
# 0  maak my wakker om [time : vyf v. m.] [date : d...         37
# 1  maak my wakker [time : nege-uur v. m.] op [dat...         20
# 2     stel 'n alarm vir [time : twee ure van nou af]         20
# 3                                               stil         40
# 4                                    janneman stilte         40
#
#                                          slot_method  \
# 0  [{'slot': 'time', 'method': 'localization'}, {...
# 1  [{'slot': 'time', 'method': 'translation'}, {'...
# 2        [{'slot': 'time', 'method': 'translation'}]
# 3                                                 []
# 4                                                 []
#
#                                            judgments
# 0  [{'worker_id': '20', 'intent_score': 1, 'slots...
# 1  [{'worker_id': '40', 'intent_score': 1, 'slots...
# 2  [{'worker_id': '64', 'intent_score': 1, 'slots...
# 3  [{'worker_id': '45', 'intent_score': 1, 'slots...
# 4  [{'worker_id': '45', 'intent_score': 1, 'slots...

# %%
english_file.head()
# Out:
#    id locale partition scenario             intent  \
# 0   0  en-US      test    alarm          alarm_set
# 1   1  en-US     train    alarm          alarm_set
# 2   2  en-US     train    alarm          alarm_set
# 3   3  en-US      test    audio  audio_volume_mute
# 4   4  en-US     train    audio  audio_volume_mute
#
#                                    utt  \
# 0      wake me up at five am this week
# 1      wake me up at nine am on friday
# 2  set an alarm for two hours from now
# 3                                quiet
# 4                           olly quiet
#
#                                            annot_utt  worker_id
# 0  wake me up at [time : five am] [date : this week]          1
# 1  wake me up at [time : nine am] on [date : friday]          1
# 2       set an alarm for [time : two hours from now]          1
# 3                                              quiet          1
# 4                                         olly quiet          1

# %%
needed_columns = ["id","utt","annot_utt"]
base_file = english_file[needed_columns]
base_file
# Out:
#           id                                  utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                                annot_utt
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
# [16521 rows x 3 columns]

# %%
def directory_checker(directory_path: str, purpose:str) -> bool:
    """
    This function checks if the directory path exists
    :param purpose: 
    :param use: 
    :param directory_path: 
    :return: 
    """
    #Check if directory exists, if it doesn't check its use, if use is output, create the directory in the parent of input directory.
    if os.path.isdir(directory_path):
        return True
    else:
        if purpose == "output":
            #Create the directory
            os.mkdir(directory_path)
            return True
        else:
            raise Exception("Invalid directory path")

# %%
'''
def create_dataframe(data: list) -> pd.DataFrame:
    # Declare an empty dataframe to append records
    df = pd.DataFrame()
    # Looping through each record
    for d in data:
    # Normalize the column levels
        record = pd.json_normalize(d)
    # Append it to the dataframe
        df =  pd.concat([df,record], ignore_index=True)
    return df

create_dataframe(english_file)
'''
# Out:
# '\ndef create_dataframe(data: list) -> pd.DataFrame:\n    # Declare an empty dataframe to append records\n    df = pd.DataFrame()\n    # Looping through each record\n    for d in data:\n    # Normalize the column levels\n        record = pd.json_normalize(d)\n    # Append it to the dataframe\n        df =  pd.concat([df,record], ignore_index=True)\n    return df\n\ncreate_dataframe(english_file)\n'

# %%
'''
import json
path = 'en-US.jsonl'
def read_json(filename: str) -> dict:
    try:
        with open(filename, "r") as f:
            data = json.loads(f.read())
    except:
        raise Exception(f"Reading {filename} file encountered an error")
    return data
def create_dataframe(data: list) -> pd.DataFrame:
    # Declare an empty dataframe to append records
    dataframe = pd.DataFrame()
    # Looping through each record
    for d in data:
    # Normalize the column levels
        record = pd.json_normalize(d)
    # Append it to the dataframe
        dataframe =  pd.concat([dataframe,record], ignore_index=True)
    return dataframe
# Read the JSON file as python dictionary
data = read_json(filename=path)
#*data=data[insert parameter according to your json data]*
dataframe = create_dataframe(data=data['data'])
# Renaming columns of the dataframe
col = {"column1":"column1","column2.key1":"key1","column2.key2":"key2"}
df = dataframe.rename(columns = col)[[*col.values()]]
df
'''
# Out:
# '\nimport json\npath = \'en-US.jsonl\'\ndef read_json(filename: str) -> dict:\n    try:\n        with open(filename, "r") as f:\n            data = json.loads(f.read())\n    except:\n        raise Exception(f"Reading {filename} file encountered an error")\n    return data\ndef create_dataframe(data: list) -> pd.DataFrame:\n    # Declare an empty dataframe to append records\n    dataframe = pd.DataFrame()\n    # Looping through each record\n    for d in data:\n    # Normalize the column levels\n        record = pd.json_normalize(d)\n    # Append it to the dataframe\n        dataframe =  pd.concat([dataframe,record], ignore_index=True)\n    return dataframe\n# Read the JSON file as python dictionary\ndata = read_json(filename=path)\n#*data=data[insert parameter according to your json data]*\ndataframe = create_dataframe(data=data[\'data\'])\n# Renaming columns of the dataframe\ncol = {"column1":"column1","column2.key1":"key1","column2.key2":"key2"}\ndf = dataframe.rename(columns = col)[[*col.values()]]\ndf\n'

# %%
len("en-US.jsonl")
# Out:
# 11

# %%
rt = "en-US.jsonl"
rt[-11:-9]
# Out:
# 'en'

# %%
def list_of_valid_files(directory_path: str) -> list:
    """
    This function returns a list of valid jsonl files in the directory path
    :param directory_path: 
    :return: 
    """
    import os 
    # Declare an empty list to store the file names
    files = []
    # Looping through each file in the path
    for file in os.listdir(directory_path):
        # Checking if the file is a jsonl file 
        #print(file)
        if file[-5:] == "jsonl":
            # Appending the file name to the list
            files.append(file)
    return files

list_of_valid_files('data')
# Out:
# ['af-ZA.jsonl',
#  'am-ET.jsonl',
#  'ar-SA.jsonl',
#  'az-AZ.jsonl',
#  'bn-BD.jsonl',
#  'ca-ES.jsonl',
#  'cy-GB.jsonl',
#  'da-DK.jsonl',
#  'de-DE.jsonl',
#  'el-GR.jsonl',
#  'en-US.jsonl',
#  'es-ES.jsonl',
#  'fa-IR.jsonl',
#  'fi-FI.jsonl',
#  'fr-FR.jsonl',
#  'he-IL.jsonl',
#  'hi-IN.jsonl',
#  'hu-HU.jsonl',
#  'hy-AM.jsonl',
#  'id-ID.jsonl',
#  'is-IS.jsonl',
#  'it-IT.jsonl',
#  'ja-JP.jsonl',
#  'jv-ID.jsonl',
#  'ka-GE.jsonl',
#  'km-KH.jsonl',
#  'kn-IN.jsonl',
#  'ko-KR.jsonl',
#  'lv-LV.jsonl',
#  'ml-IN.jsonl',
#  'mn-MN.jsonl',
#  'ms-MY.jsonl',
#  'my-MM.jsonl',
#  'nb-NO.jsonl',
#  'nl-NL.jsonl',
#  'pl-PL.jsonl',
#  'pt-PT.jsonl',
#  'ro-RO.jsonl',
#  'ru-RU.jsonl',
#  'sl-SL.jsonl',
#  'sq-AL.jsonl',
#  'sv-SE.jsonl',
#  'sw-KE.jsonl',
#  'ta-IN.jsonl',
#  'te-IN.jsonl',
#  'th-TH.jsonl',
#  'tl-PH.jsonl',
#  'tr-TR.jsonl',
#  'ur-PK.jsonl',
#  'vi-VN.jsonl',
#  'zh-CN.jsonl',
#  'zh-TW.jsonl']

# %%
def full_path_generator(directory_path: str, filepath: str) -> str:
    """
    This function returns a str of the full path of the files
    :param filepath: 
    :param directory_path:
    :return:
    """
    full_path = os.path.join(directory_path, filepath)
    # Appending the full path to the list
    return full_path

# %%
import logging
from pandas import DataFrame
from typing import *
from io import StringIO
def dataframe_gen_from_jsonl(file_path: str) :
    df_dictionary: Dict[str, List[Any]] = {}
    # read the file contents line by line
    try:
        df = pd.read_json(file_path,orient='records',lines=True)
        return df
    except Exception as e:
        print(e)
        print(" "+"Something went wrong reading file"+f" {file_path}")
        return pd.DataFrame()

# %%
def df_to_excel(df: DataFrame, output_path: str) -> bool:
    """
    This function returns a bool of whether the dataframe was successfully saved to excel
    :param df: 
    :param output_path: 
    :return: 
    """
    try:
        if df.empty:
            raise Exception("Dataframe is empty")
        else:
            df.to_excel(output_path, index=False)
            return True
    except Exception as e:
        print(e)
        raise Exception("Error saving to excel")

# %%
def excel_files_gen(input_directory_path: str, output_directory_path: str) -> list:
    """
    This function returns a list of excel files generated from the jsonl files
    :param output_directory_path: 
    :param input_directory_path: 
    :return: 
    """
        # Declare an empty list to store the Excel file names
    excel_files = []
    # Looping through each file in the list of full paths
    files = list_of_valid_files(directory_path=input_directory_path)
    # remove en-US.jsonl from the list of files
    files.remove("en-US.jsonl")
    for file in files:
        langauge_code = file[-11:-9]
        language_file_path = full_path_generator(directory_path=input_directory_path, filepath=file)
        df = per_language_pivot_en(lang_directory_path=input_directory_path,filepath=file,input_directory_path=input_directory_path)
        print(df)
        # Output the dataframe to excel to specified output directory
        # the output name format is 
        output_path = os.path.join(output_directory_path, f"en-{langauge_code}.xlsx")
        df_to_excel(df=df, output_path=output_path)
        # Appending the excel file name to the list
        excel_files.append(f"en-{langauge_code}.xlsx")
    return excel_files

# %%
# Use fullpathgenerator 
def per_language_pivot_en(lang_directory_path: str,filepath:str,input_directory_path) -> DataFrame:
    '''
    This function returns a dataframe where utt, annon_utt are added to the base dataframe 
    for the specific passed file path
    :param lang_directory_path: 
    :param input_directory_path: 
    :param filepath: 
    :return: 
    '''
    #Generating english base DataFrame
    english_base_df = en_base_df(input_directory_path=input_directory_path)
    # Getting the language code from the file path
    language_code = filepath[-11:-9]
    # Getting the dataframe for the specific language
   
    filepath = full_path_generator(directory_path=lang_directory_path, filepath=filepath)
    print(filepath)
    df = dataframe_gen_from_jsonl(file_path=filepath)
    # Renaming the columns
    if df is not None:
        df = df.rename(columns={"id": "id", "utt": f"{language_code}_utt", "annot_utt": f"{language_code}_annot"})
        df = df[["id",f"{language_code}_utt", f"{language_code}_annot"]]
         #reset index
        df.reset_index(drop=True, inplace=True)
        #drop id column
        df.drop(columns=["id"], inplace=True)
        # Merging the dataframes
        merged_df = pd.concat([english_base_df, df], axis=1)
        # Returning the merged dataframe
        return merged_df
    else:
        print(Exception)

# %%
import FileParsing
'''
def per_language_pivot_en(self, filepath: str) -> DataFrame:
    """
    This function returns a dataframe where utt, annon_utt are added to the base dataframe
    for the specific passed file path
    :param filepath:
    :return:
    """

    # Generating english base DataFrame
    english_base_df = en_base_df()
    # Getting the language code from the file path
    language_code = filepath[-11:-9]
    print(filepath)
    # Getting the dataframe for the specific language
    file_path = full_path_generator(directory_path=self.input_directory_path, filepath=filepath)
    df: DataFrame = dataframe_gen_from_jsonl(file_path=file_path)
    # Renaming the columns
    df = df.rename(columns={"id": "id", "utt": f"{language_code}_utt", "annot_utt": f"{language_code}_annot"})
    df = df[["id", f"{language_code}_utt", f"{language_code}_annot"]]
    # Merging the dataframes
    merged_df = pd.merge(left=english_base_df, right=df, on="id", how="left")
    # Returning the merged dataframe
    return merged_df
    '''
# Out:
# '\ndef per_language_pivot_en(self, filepath: str) -> DataFrame:\n    """\n    This function returns a dataframe where utt, annon_utt are added to the base dataframe\n    for the specific passed file path\n    :param filepath:\n    :return:\n    """\n\n    # Generating english base DataFrame\n    english_base_df = en_base_df()\n    # Getting the language code from the file path\n    language_code = filepath[-11:-9]\n    print(filepath)\n    # Getting the dataframe for the specific language\n    file_path = full_path_generator(directory_path=self.input_directory_path, filepath=filepath)\n    df: DataFrame = dataframe_gen_from_jsonl(file_path=file_path)\n    # Renaming the columns\n    df = df.rename(columns={"id": "id", "utt": f"{language_code}_utt", "annot_utt": f"{language_code}_annot"})\n    df = df[["id", f"{language_code}_utt", f"{language_code}_annot"]]\n    # Merging the dataframes\n    merged_df = pd.merge(left=english_base_df, right=df, on="id", how="left")\n    # Returning the merged dataframe\n    return merged_df\n    '

# %%
def en_base_df(input_directory_path: str) -> DataFrame:
    """
    This function returns the base dataframe for the english language
    :return: 
    """
    # Getting the list of valid files
    files = list_of_valid_files(directory_path=input_directory_path)
    # Getting the full paths of the files
    # Checking for en-US.jsonl file in files
    if "en-US.jsonl" in files:
        # Getting the full path of the en-US.jsonl file
        en_us_path = full_path_generator(directory_path=input_directory_path, filepath="en-US.jsonl")
        print(en_us_path)
        # Generating the dataframe
        en_us_df = dataframe_gen_from_jsonl(file_path=en_us_path)
        # Renaming the columns
        en_us_df = en_us_df.rename(columns={"id": "id", "utt": "en-US_utt", "annot_utt": "en-US_annot"})
        print(en_us_df)
        en_us_df = en_us_df[["id", "en-US_utt", "en-US_annot"]]
        # Returning the dataframe
        return en_us_df
    else:
        raise Exception("en-US.jsonl file is not present in the directory path")

# %%
excel_files_gen(input_directory_path="data", output_directory_path="outputs")
# Out:
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\af-ZA.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                         af_utt  \
# 0         maak my wakker om vyf v. m. die week
# 1      maak my wakker nege-uur v. m. op vrydag
# 2        stel 'n alarm vir twee ure van nou af
# 3                                         stil
# 4                              janneman stilte
# ...                                        ...
# 16516                           het ek e-posse
# 16517                   watter e-posse is nuut
# 16518          het ek nuwe eposse vanaf pieter
# 16519           het john vir my ŉ epos gestuur
# 16520                  kyk na epos van jeff af
#
#                                                 af_annot
# 0      maak my wakker om [time : vyf v. m.] [date : d...
# 1      maak my wakker [time : nege-uur v. m.] op [dat...
# 2         stel 'n alarm vir [time : twee ure van nou af]
# 3                                                   stil
# 4                                        janneman stilte
# ...                                                  ...
# 16516                                     het ek e-posse
# 16517                             watter e-posse is nuut
# 16518         het ek nuwe eposse vanaf [person : pieter]
# 16519          het [person : john] vir my ŉ epos gestuur
# 16520                 kyk na epos van [person : jeff] af
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\am-ET.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                      am_utt  \
# 0      በዚህ ሳምንት ከንጋቱ አስራአንድ ሰዓት ከእንቅልፍ አንቃኝ
# 1                አርብ ዘጠኝ ኤ. ኤም. ሰዓት ላይ አንቃኝ
# 2             ከሁለት ሰአት በኀላ ሚጠራ የማንቂያ ደውል ያዝ
# 3                                       ጸጥታ
# 4                                  ኦሊ ዝም በል
# ...                                     ...
# 16516                              ኢሜይል አለኝ
# 16517                      ምን ኢሜይሎች አዲስ ናቸው
# 16518                እኔ ከ ሙሉጌታ አዲስ ኢሜይል አሉኝ
# 16519                         አበበ ኢሜል ልኮልኛል
# 16520                       የጫላ ኢሜይልን ያረጋግጡ
#
#                                                 am_annot
# 0      [date : በዚህ ሳምንት] [time : ከንጋቱ አስራአንድ ሰዓት] ከእን...
# 1           [date : አርብ] [time : ዘጠኝ ኤ. ኤም.] ሰዓት ላይ አንቃኝ
# 2                 [time : ከሁለት ሰአት በኀላ ሚጠራ] የማንቂያ ደውል ያዝ
# 3                                                    ጸጥታ
# 4                                               ኦሊ ዝም በል
# ...                                                  ...
# 16516                                           ኢሜይል አለኝ
# 16517                                   ምን ኢሜይሎች አዲስ ናቸው
# 16518                  እኔ ከ [person : ሙሉጌታ] አዲስ ኢሜይል አሉኝ
# 16519                           [person : አበበ] ኢሜል ልኮልኛል
# 16520                         [person : የጫላ] ኢሜይልን ያረጋግጡ
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\ar-SA.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                  ar_utt  \
# 0          صحيني خمسة الفجر هذا الأسبوع
# 1          صحيني تسعة الصباح يوم الجمعة
# 2           حط منبه بعد ساعتين من الحين
# 3                                  هدوء
# 4                             olly هدوء
# ...                                 ...
# 16516       ابي أعرف اذا وصلتني ايميلات
# 16517              وش الإيميلات الجديدة
# 16518     هل عندي ايميلات جديدة من فيصل
# 16519  ابي أعرف اذا سلمان أرسل لي email
# 16520         شوف اذا فيه email من وائل
#
#                                              ar_annot
# 0      صحيني [time : خمسة الفجر] [date : هذا الأسبوع]
# 1      صحيني [time : تسعة الصباح] يوم [date : الجمعة]
# 2                حط منبه [time : بعد ساعتين من الحين]
# 3                                                هدوء
# 4                                           olly هدوء
# ...                                               ...
# 16516                     ابي أعرف اذا وصلتني ايميلات
# 16517                            وش الإيميلات الجديدة
# 16518        هل عندي ايميلات جديدة من [person : فيصل]
# 16519     ابي أعرف اذا [person : سلمان] أرسل لي email
# 16520            شوف اذا فيه email من [person : وائل]
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\az-AZ.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                            az_utt  \
# 0          bu həftə məni səhər saat beşdə oyandır
# 1      cümə günü səhər saat doqquzda məni oyandır
# 2             saatın zəngini iki saat sonraya qur
# 3                                           sakit
# 4                                      olly sakit
# ...                                           ...
# 16516                           mənə emaillər var
# 16517                      hansı emaillər yenidir
# 16518              mənim azərdən yeni emailim var
# 16519                   cavid mənə email göndərib
# 16520                caviddən imeyl gəlibmi yoxla
#
#                                                 az_annot
# 0      [date : bu həftə] məni [time : səhər saat beşd...
# 1      [date : cümə günü] [time : səhər saat doqquzda...
# 2           saatın zəngini [time : iki saat sonraya] qur
# 3                                                  sakit
# 4                                             olly sakit
# ...                                                  ...
# 16516                                  mənə emaillər var
# 16517                             hansı emaillər yenidir
# 16518          mənim [person : azərdən] yeni emailim var
# 16519               [person : cavid] mənə email göndərib
# 16520            [person : caviddən] imeyl gəlibmi yoxla
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\bn-BD.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                                  bn_utt  \
# 0              এই সপ্তাহে পাঁচটায় আমাকে ঘুম থেকে জাগাও
# 1                আমাকে শুক্রবার সকাল ন-টায় জাগিয়ে দেবেন
# 2      এখন থেকে দুই ঘন্টার জন্য একটি অ্যালার্ম সেট করুন
# 3                                                 শান্ত
# 4                                             অলি শান্ত
# ...                                                 ...
# 16516                                 আমার কি ইমেইল আছে
# 16517                                 কোন ইমেলগুলো নতুন
# 16518                   আমার কি বিনয় থেকে নতুন ইমেল আছে
# 16519                 রায়হান আমাকে একটি ইমেইল পাঠিয়েছে
# 16520                           সুদীপ এর ইমেইল চেক করুন
#
#                                                 bn_annot
# 0      [date : এই সপ্তাহে] [time : পাঁচটায়] আমাকে ঘু...
# 1      আমাকে [date : শুক্রবার] [time : সকাল ন-টায়] জা...
# 2      [time : এখন থেকে দুই ঘন্টার] জন্য একটি অ্যালার...
# 3                                                  শান্ত
# 4                                              অলি শান্ত
# ...                                                  ...
# 16516                                  আমার কি ইমেইল আছে
# 16517                                  কোন ইমেলগুলো নতুন
# 16518         আমার কি [person : বিনয়] থেকে নতুন ইমেল আছে
# 16519       [person : রায়হান] আমাকে একটি ইমেইল পাঠিয়েছে
# 16520                 [person : সুদীপ] এর ইমেইল চেক করুন
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\ca-ES.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                                 ca_utt  \
# 0       desperta’m a les cinc del matí aquesta setmana
# 1             desperta'm a les nou a. m. del divendres
# 2              posa una alarma per d’aquí a dues hores
# 3                                                calla
# 4                                            ali calla
# ...                                                ...
# 16516                                     tinc correus
# 16517               quins correus electrònics són nous
# 16518          tinc nous correus electrònics d'en pere
# 16519         m'ha enviat un correu electrònic en joan
# 16520  comprova els correus electrònics rebuts de joan
#
#                                                 ca_annot
# 0      desperta’m a les [time : cinc del matí] [date ...
# 1      desperta'm a les [time : nou a. m.] del [date ...
# 2       posa una alarma per [time : d’aquí a dues hores]
# 3                                                  calla
# 4                                              ali calla
# ...                                                  ...
# 16516                                       tinc correus
# 16517                 quins correus electrònics són nous
# 16518  tinc nous correus electrònics d'en [person : p...
# 16519  m'ha enviat un correu electrònic en [person : ...
# 16520  comprova els correus electrònics rebuts de [pe...
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\cy-GB.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                                 cy_utt  \
# 0                 deffra fi am pump y bore wythnos yma
# 1               deffra fi am naw y bore ar dydd gwener
# 2               gosodwch larwm ar gyfer dwy awr o nawr
# 3                                                tawel
# 4                                           olly tawel
# ...                                                ...
# 16516                               a oes gennyf ebyst
# 16517                             pa ebyst sy'n newydd
# 16518  a oes gennyf unrhyw ebyst newydd oddi wrth john
# 16519                   ydy john wedi anfon ebost i fi
# 16520                         gwiriwch ebost wrth john
#
#                                                 cy_annot
# 0      deffra fi am [time : pump y bore] [date : wyth...
# 1      deffra fi am [time : naw y bore] ar [date : dy...
# 2        gosodwch larwm ar gyfer [time : dwy awr o nawr]
# 3                                                  tawel
# 4                                             olly tawel
# ...                                                  ...
# 16516                                 a oes gennyf ebyst
# 16517                               pa ebyst sy'n newydd
# 16518  a oes gennyf unrhyw ebyst newydd oddi wrth [pe...
# 16519          ydy [person : john] wedi anfon ebost i fi
# 16520                gwiriwch ebost wrth [person : john]
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\da-DK.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                  da_utt  \
# 0         væk mig klokken fem denne uge
# 1             væk mig klokken ni fredag
# 2      sæt en alarm til to timer fra nu
# 3                                stille
# 4                           olly stille
# ...                                 ...
# 16516                    har jeg emails
# 16517      hvad for nogle emails er nye
# 16518       har jeg nye emails fra john
# 16519       har john sendt mig en email
# 16520               tjek email fra john
#
#                                               da_annot
# 0      væk mig [time : klokken fem] [date : denne uge]
# 1          væk mig klokken [time : ni] [date : fredag]
# 2            sæt en alarm til [time : to timer fra nu]
# 3                                               stille
# 4                                          olly stille
# ...                                                ...
# 16516                                   har jeg emails
# 16517                     hvad for nogle emails er nye
# 16518           har jeg nye emails fra [person : john]
# 16519           har [person : john] sendt mig en email
# 16520                   tjek email fra [person : john]
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\de-DE.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                              de_utt  \
# 0        wecke mich in dieser woche um fünf uhr auf
# 1              weck mich am freitag um neun uhr auf
# 2      stell einen wecker für zwei stunden ab jetzt
# 3                                             leise
# 4                                        olly leise
# ...                                             ...
# 16516                               habe ich emails
# 16517                        welche emails sind neu
# 16518                habe ich neue emails von horst
# 16519           hat jürgen mir eine email geschickt
# 16520                prüfe meine email von johannes
#
#                                                 de_annot
# 0      wecke mich in [date : dieser woche] um [time :...
# 1      weck mich am [date : freitag] um [time : neun ...
# 2      stell einen wecker für [time : zwei stunden ab...
# 3                                                  leise
# 4                                             olly leise
# ...                                                  ...
# 16516                                    habe ich emails
# 16517                             welche emails sind neu
# 16518          habe ich neue emails von [person : horst]
# 16519     hat [person : jürgen] mir eine email geschickt
# 16520          prüfe meine email von [person : johannes]
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\el-GR.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                               el_utt  \
# 0      ξύπνησε με στις πέντε π. μ. αυτή την εβδομάδα
# 1            ξύπνα με στις εννιά π. μ. την παρασκευή
# 2          όρισε ένα ξυπνητήρι για δύο ώρες απο τώρα
# 3                                              ήσυχα
# 4                                         olly σιωπή
# ...                                              ...
# ...
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                             ur_utt  \
# 0             مجھے اس ہفتے صبح کے پانچ بجے جگا دیں
# 1                  مجھے جمعہ کی صبح نو بجے جگا دیں
# 2             اب سے دو گھنٹے کے لیے الارم سیٹ کریں
# 3                                            خاموش
# 4                                    علی خاموش رہو
# ...                                            ...
# 16516                کیا میرے پاس الیکٹرانک میل ہے
# 16517                       کون سی ای میلز نئی ہیں
# 16518  کیا میرے پاس عامر کی طرف سے نئی ای میلز ہیں
# 16519              سحر نے مجھے ایک ای میل بھیجا ہے
# 16520                      زاھد سے ای میل چیک کریں
#
#                                                 ur_annot
# 0      مجھے [date : اس ہفتے] [time : صبح کے پانچ بجے]...
# 1      مجھے [date : جمعہ] کی صبح [time : نو بجے] جگا دیں
# 2          [time : اب سے دو گھنٹے] کے لیے الارم سیٹ کریں
# 3                                                  خاموش
# 4                                          علی خاموش رہو
# ...                                                  ...
# 16516                      کیا میرے پاس الیکٹرانک میل ہے
# 16517                             کون سی ای میلز نئی ہیں
# 16518  کیا میرے پاس [person : عامر] کی طرف سے نئی ای ...
# 16519         [person : سحر] نے مجھے ایک ای میل بھیجا ہے
# 16520                 [person : زاھد] سے ای میل چیک کریں
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\vi-VN.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot  \
# 0      wake me up at [time : five am] [date : this week]
# 1      wake me up at [time : nine am] on [date : friday]
# 2           set an alarm for [time : two hours from now]
# 3                                                  quiet
# 4                                             olly quiet
# ...                                                  ...
# 16516                                   do i have emails
# 16517                                what emails are new
# 16518          do i have new emails from [person : john]
# 16519               has [person : john] sent me an email
# 16520                   check email from [person : john]
#
#                                             vi_utt  \
# 0      đánh thức tôi dậy lúc năm giờ sáng tuần này
# 1       gọi tôi dậy lúc chín giờ sáng ngày thứ sáu
# 2         cài báo thức trong hai giờ kể từ bây giờ
# 3                                          im lặng
# 4                                     olly im lặng
# ...                                            ...
# 16516                       tôi có email nào không
# 16517                 những thư điện tử nào là mới
# 16518      tôi có thư điện tử mới nào từ huy không
# 16519                  hùng có gửi tôi email không
# 16520                       kiểm tra email của huy
#
#                                                 vi_annot
# 0      đánh thức tôi dậy lúc [time : năm giờ sáng] [d...
# 1      gọi tôi dậy lúc [time : chín giờ sáng] ngày [d...
# 2      cài báo thức trong [time : hai giờ kể từ bây giờ]
# 3                                                im lặng
# 4                                           olly im lặng
# ...                                                  ...
# 16516                             tôi có email nào không
# 16517                       những thư điện tử nào là mới
# 16518  tôi có thư điện tử mới nào từ [person : huy] k...
# 16519             [person : hùng] có gửi tôi email không
# 16520                  kiểm tra email của [person : huy]
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\zh-CN.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot          zh_utt  \
# 0      wake me up at [time : five am] [date : this week]        这周五点叫我起床
# 1      wake me up at [time : nine am] on [date : friday]      星期五早上九点叫醒我
# 2           set an alarm for [time : two hours from now]       设个两小时后的闹钟
# 3                                                  quiet              安静
# 4                                             olly quiet         olly 安静
# ...                                                  ...             ...
# 16516                                   do i have emails         我有电子邮件吗
# 16517                                what emails are new       哪些电子邮件是新的
# 16518          do i have new emails from [person : john]  我有来自于家俊的新电子邮件吗
# 16519               has [person : john] sent me an email     李雷给我发电子邮件了吗
# 16520                   check email from [person : john]     查看来自家明的电子邮件
#
#                               zh_annot
# 0         [date : 这周] [time : 五点] 叫我起床
# 1      [date : 星期五] 早上 [time : 九点] 叫醒我
# 2                 设个 [time : 两小时后] 的闹钟
# 3                                   安静
# 4                              olly 安静
# ...                                ...
# 16516                          我有电子邮件吗
# 16517                        哪些电子邮件是新的
# 16518      我有来自于 [person : 家俊] 的新电子邮件吗
# 16519          [person : 李雷] 给我发电子邮件了吗
# 16520         查看来自 [person : 家明] 的电子邮件
#
# [16521 rows x 5 columns]
# data\en-US.jsonl
#           id locale partition scenario             intent  \
# 0          0  en-US      test    alarm          alarm_set
# 1          1  en-US     train    alarm          alarm_set
# 2          2  en-US     train    alarm          alarm_set
# 3          3  en-US      test    audio  audio_volume_mute
# 4          4  en-US     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  en-US     train    email        email_query
# 16517  17177  en-US     train    email        email_query
# 16518  17178  en-US     train    email        email_query
# 16519  17179  en-US      test    email        email_query
# 16520  17180  en-US     train    email        email_query
#
#                                  en-US_utt  \
# 0          wake me up at five am this week
# 1          wake me up at nine am on friday
# 2      set an alarm for two hours from now
# 3                                    quiet
# 4                               olly quiet
# ...                                    ...
# 16516                     do i have emails
# 16517                  what emails are new
# 16518       do i have new emails from john
# 16519            has john sent me an email
# 16520                check email from john
#
#                                              en-US_annot  worker_id
# 0      wake me up at [time : five am] [date : this week]          1
# 1      wake me up at [time : nine am] on [date : friday]          1
# 2           set an alarm for [time : two hours from now]          1
# 3                                                  quiet          1
# 4                                             olly quiet          1
# ...                                                  ...        ...
# 16516                                   do i have emails         12
# 16517                                what emails are new         12
# 16518          do i have new emails from [person : john]         12
# 16519               has [person : john] sent me an email         12
# 16520                   check email from [person : john]         12
#
# [16521 rows x 8 columns]
# data\zh-TW.jsonl
#           id                            en-US_utt  \
# 0          0      wake me up at five am this week
# 1          1      wake me up at nine am on friday
# 2          2  set an alarm for two hours from now
# 3          3                                quiet
# 4          4                           olly quiet
# ...      ...                                  ...
# 16516  17176                     do i have emails
# 16517  17177                  what emails are new
# 16518  17178       do i have new emails from john
# 16519  17179            has john sent me an email
# 16520  17180                check email from john
#
#                                              en-US_annot          zh_utt  \
# 0      wake me up at [time : five am] [date : this week]       這週早上五點叫醒我
# 1      wake me up at [time : nine am] on [date : friday]      禮拜五早上九點叫醒我
# 2           set an alarm for [time : two hours from now]       設定兩小時後的鬧鐘
# 3                                                  quiet              安靜
# 4                                             olly quiet           奧利很安靜
# ...                                                  ...             ...
# 16516                                   do i have emails         我有電子郵件嗎
# 16517                                what emails are new        哪些是新電子郵件
# 16518          do i have new emails from [person : john]   我有來自約翰的新電子郵件嗎
# 16519               has [person : john] sent me an email  約翰有寄 email 給我嗎
# 16520                   check email from [person : john]            志豪郵件
#
#                              zh_annot
# 0       [date : 這週] [time : 早上五點] 叫醒我
# 1      [date : 禮拜五] [time : 早上九點] 叫醒我
# 2                設定 [time : 兩小時後] 的鬧鐘
# 3                                  安靜
# 4                               奧利很安靜
# ...                               ...
# 16516                         我有電子郵件嗎
# 16517                        哪些是新電子郵件
# 16518      我有來自 [person : 約翰] 的新電子郵件嗎
# 16519      [person : 約翰] 有寄 email 給我嗎
# 16520                [person : 志豪] 郵件
#
# [16521 rows x 5 columns]
# ['en-af.xlsx',
#  'en-am.xlsx',
#  'en-ar.xlsx',
#  'en-az.xlsx',
#  'en-bn.xlsx',
#  'en-ca.xlsx',
#  'en-cy.xlsx',
#  'en-da.xlsx',
#  'en-de.xlsx',
#  'en-el.xlsx',
#  'en-es.xlsx',
#  'en-fa.xlsx',
#  'en-fi.xlsx',
#  'en-fr.xlsx',
#  'en-he.xlsx',
#  'en-hi.xlsx',
#  'en-hu.xlsx',
#  'en-hy.xlsx',
#  'en-id.xlsx',
#  'en-is.xlsx',
#  'en-it.xlsx',
#  'en-ja.xlsx',
#  'en-jv.xlsx',
#  'en-ka.xlsx',
#  'en-km.xlsx',
#  'en-kn.xlsx',
#  'en-ko.xlsx',
#  'en-lv.xlsx',
#  'en-ml.xlsx',
#  'en-mn.xlsx',
#  'en-ms.xlsx',
#  'en-my.xlsx',
#  'en-nb.xlsx',
#  'en-nl.xlsx',
#  'en-pl.xlsx',
#  'en-pt.xlsx',
#  'en-ro.xlsx',
#  'en-ru.xlsx',
#  'en-sl.xlsx',
#  'en-sq.xlsx',
#  'en-sv.xlsx',
#  'en-sw.xlsx',
#  'en-ta.xlsx',
#  'en-te.xlsx',
#  'en-th.xlsx',
#  'en-tl.xlsx',
#  'en-tr.xlsx',
#  'en-ur.xlsx',
#  'en-vi.xlsx',
#  'en-zh.xlsx',
#  'en-zh.xlsx']

# %%
#per_language_pivot_en(directory_path='data',filepath="af-ZA.jsonl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 per_language_pivot_en(directory_path='data',filepath="af-ZA.jsonl")
#
# TypeError: per_language_pivot_en() got an unexpected keyword argument 'directory_path'

# %%
def partition(df: DataFrame, part:str) -> DataFrame:
    part = part.lower()
    if part == "train" or part == "dev" or part == "test":
        df = df[df["partition"] == part]
        return df
    else:
        raise Exception("Invalid partition")

# %%
from json import loads, dumps
def save_to_jsonl(df: DataFrame, output_path: str, lines:bool) -> bool:
    try:
        if df.empty:
            raise Exception("Dataframe is empty")
        else:
            df.to_json(output_path, orient="records", lines=lines)
            return True 
    except Exception as e:
        print(e)
        raise Exception("Error saving to jsonl")

# %%
def partitions_gen(df: DataFrame) -> list:
    parts =["train", "dev", "test"]
    partitions = []
    for part in parts:
        dff = partition(df=df, part=part)
        partitions.append(dff)
    return partitions

# %%
def task21(output_directory_path: str, input_directory_path: str, languages: list) -> None:
    files = list_of_valid_files(directory_path=input_directory_path)
    #Check directories exist
    if(directory_checker(directory_path=input_directory_path, purpose="input") and
    directory_checker(directory_path=output_directory_path, purpose="output")):
        supported_langs = []
        counter = 0 
        #language generating function. 
        for file in files:
            ++counter
            language_code = file[-11:-9]
            supported_langs.append(language_code)
            #print(files)
        print(supported_langs)
        for file in files: 
            for i in range(len(languages)):
                if file[-11:-9] == languages[i] :
                    file_path = full_path_generator(directory_path=input_directory_path, filepath=file)
                    print(file_path)
                    dff = dataframe_gen_from_jsonl(file_path=file_path)
                    partitions = partitions_gen(df=dff)
                    for j in range(len(partitions)):
                        partition_name = ""
                        if j == 0:
                            partition_name = "train"
                        elif j == 1:
                            partition_name = "dev"
                        else:
                            partition_name = "test"
                            
                        out_dir_path = os.path.join(output_directory_path, f"{partition_name}")
                        os.makedirs(out_dir_path,exist_ok=True)
                        #print(out_dir_path)
                        output_path = full_path_generator(out_dir_path,f"{languages[i]}-{partition_name}.jsonl")
                        print(output_path)
                        save_to_jsonl(df=partitions[j], output_path=output_path)
                       
                else:
                    continue
          
    else:
        raise Exception("Invalid directory path")

# %%
task21(output_directory_path="outputs", input_directory_path="data", languages=["en", "de", "sw"])
# Out:
# ['af', 'am', 'ar', 'az', 'bn', 'ca', 'cy', 'da', 'de', 'el', 'en', 'es', 'fa', 'fi', 'fr', 'he', 'hi', 'hu', 'hy', 'id', 'is', 'it', 'ja', 'jv', 'ka', 'km', 'kn', 'ko', 'lv', 'ml', 'mn', 'ms', 'my', 'nb', 'nl', 'pl', 'pt', 'ro', 'ru', 'sl', 'sq', 'sv', 'sw', 'ta', 'te', 'th', 'tl', 'tr', 'ur', 'vi', 'zh', 'zh']
# data\de-DE.jsonl
# outputs\train\de-train.jsonl
# outputs\dev\de-dev.jsonl
# outputs\test\de-test.jsonl
# data\en-US.jsonl
# outputs\train\en-train.jsonl
# outputs\dev\en-dev.jsonl
# outputs\test\en-test.jsonl
# data\sw-KE.jsonl
# outputs\train\sw-train.jsonl
# outputs\dev\sw-dev.jsonl
# outputs\test\sw-test.jsonl

# %%
output_directory_path = "outputs"
partition_name = "Kamau"
output_dir = output_directory_path+str(f"\\{partition_name}")
output_dir
# Out:
# 'outputs\\Kamau'

# %%
import json
df = DataFrame
def task22(lang_input_directory :str)-> json:
    # check if the directory name ends in train 
    new_df = DataFrame
    if lang_input_directory[-5:] == 'train':
        df_list = []
        print('yes')
        files = list_of_valid_files(directory_path=lang_input_directory)
        #print(files)
        language_codes = []
        
        for i in range(len(files)):
            
            file = files[i]
            language_code = file[-15:-12]
            language_codes.append(language_code)
            new_df = dataframe_gen_from_jsonl(file_path=full_path_generator(directory_path=lang_input_directory, filepath=file))
            new_df = new_df[["id", "utt"]]
            new_df = new_df.rename(columns={"id": "id", "utt": f"{language_code}_utt"})
            new_df = new_df[['id',f'{language_code}_utt']]
            new_df.reset_index(drop=True, inplace=True)
            df_list.append(new_df)
        df = pd.concat(df_list, axis=1, join="inner")
        df.head(40)
        df.reset_index(drop=True, inplace=True)
        #Remove the redundant columns of the merged dataFrame
        df = df.loc[:,~df.columns.duplicated()]
        df = df[['id', 'en_utt', 'de_utt', 'sw_utt']]
        print(df.head())
        df.to_json("outputs\\train.json", orient="records", lines=False)
        with open("outputs\\train.json", "r") as read_file:
            print("Read JSON file")
            jsonsl = json.load(read_file)
            pretty_json = json.dumps(jsonsl, indent=4, separators=(',', ': '), sort_keys=True)
            print("Displaying Pretty Printed JSON Data")
            #print(pretty_json)
            
    else:
        raise Exception("Invalid directory")

# %%
task22(lang_input_directory="outputs\\train")
# Out:
# yes
#    id                               en_utt  \
# 0   1      wake me up at nine am on friday
# 1   2  set an alarm for two hours from now
# 2   4                           olly quiet
# 3   5                                 stop
# 4   6           olly pause for ten seconds
#
#                                          de_utt  \
# 0          weck mich am freitag um neun uhr auf
# 1  stell einen wecker für zwei stunden ab jetzt
# 2                                    olly leise
# 3                                         stopp
# 4               olly pausiere für zehn sekunden
#
#                                      sw_utt
# 0           niamshe saa tatu asubuhi ijumaa
# 1  weka kengele ya masaa mawili kutoka sasa
# 2                              olly nyamaza
# 3                                     wacha
# 4              olly tuliza kwa sekunde kumi
# Read JSON file
# Displaying Pretty Printed JSON Data

# %%
df
# Out:
# pandas.core.frame.DataFrame
